# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarpattnaik8080/Learning_2026/blob/main/MiniProject01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Personal Information Card
name="Omkar"
age=24
city="Bengaluru"

print(name,city,age)
# Out:
# Omkar Bengaluru 24
