# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarpattnaik8080/Learning_2026/blob/main/Python(2026).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python**

# %%
##Comments

##single line comment

#i am omkar pattnaik

##Multi line comment
"""this is omkar
i am from

Bhubaneswar"""
# Out:
# 'this is omkar\ni am from\n\nBhubaneswar'

# %%
##Variables

##They are exactly like boxes
