# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarpattnaik8080/Learning_2026/blob/main/MiniProject02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mini Project 2

num1=int(input("Enter first number: "))
num2=int(input("Enter second number: "))
num3=int(input("Enter third number: "))

sum=num1+num2+num3
diff=num1-num2-num3
prod=num1*num2*num3

print(sum,diff,prod)
# Out:
# Enter first number: 2
# Enter second number: 3
# Enter third number: 4
# 9 -5 24
